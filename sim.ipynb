# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('DOEXT01.csv')
df = df[['contador', 'TIPOBITO', 'DTOBITO', 'NATURAL', 'DTNASC', 'IDADE', 'SEXO','RACACOR']]
df.columns
# Out:
# /home/joaocaumo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['contador', 'TIPOBITO', 'DTOBITO', 'NATURAL', 'DTNASC', 'IDADE', 'SEXO',
#        'RACACOR'],
#       dtype='object')

# %%
#### MAKING SOME CHANGES TO THE DATA ####
df['DTOBITO'] = df['DTOBITO'].astype('str')
df['ANOSOBITO'] = df['DTOBITO'].str[-4:]
df['MESOBITO'] = df['DTOBITO'].str[-6:-4]
df['IDADE'] = df['IDADE'].astype('str')
df['DTOBITO'] = df['DTOBITO'].astype('int32')
df['MESOBITO'] = df['MESOBITO'].astype('int32')
df['ANOSOBITO'] = df['ANOSOBITO'].astype('int32')
#df['IDADEANOS'] = df['IDADE'].str[1:] #ALGUNS NAO TINHAM ANOS, ENTAO NAO TINHA CARACTERES APARTIR DO PRIMEIRO, UTILIZANDO O METO ABAIXO RESOLVEMOS ISSO.
#df['IDADEANOS'] = df[df['IDADE']
#df['IDADEANOS'] = df['IDADEANOS'].dropna(axis=0)
df['IDADEANOS'] = df['IDADE'].astype('int32')
df['IDADEANOS'] = df['IDADEANOS'].astype('str')
df['IDADEANOS'] = df['IDADEANOS'].str[1:]
#df.loc[(df['MESOBITO'] == 5)]
ndf = df[['SEXO', 'IDADEANOS']]
df = df.fillna(0) #CHANGING NAN TO 0
#df['IDADEANOS'] = df['IDADEANOS'].astype('int32')
#df = df.sort_values(['MESOBITO'])
#df = df.groupby(['IDADEANOS']).mean()
#df = df.reset_index(drop=True)
dff = df
df = df.reset_index(drop=True)
#f = df.groupby(['SEXO']).mean()
dff = dff.sort_values(['RACACOR'])
dff = dff.reset_index(drop=True)
print(df[df['MESOBITO'] == 2])
# Out:
#         contador  TIPOBITO   DTOBITO  NATURAL      DTNASC IDADE  SEXO  \
# 4              5         2  20022001    800.0  16011980.0   421     2
# 23            24         2  12022001      0.0         0.0   999     1
# 32            33         2  13022001    800.0  29011962.0   439     1
# 36            37         2  28022001    800.0  24021988.0   413     1
# 135          136         2  26022001    800.0  22021949.0   452     2
# ...          ...       ...       ...      ...         ...   ...   ...
# 119734    119735         2  14022001    822.0  14021951.0   450     1
# 119735    119736         2  26022001    853.0  29091986.0   414     1
# 119822    119823         2  27022001    829.0  14101964.0   436     1
# 119827    119828         2   4022001    853.0   7121962.0   438     1
# 120952    120953         2  13022001    823.0  20041940.0   460     1
#
#         RACACOR  ANOSOBITO  MESOBITO IDADEANOS
# 4           4.0       2001         2        21
# ...

# %%
ybarra = [102311, 18544]
xbarra = [1,2]
plt.figure(figsize=(5,4), dpi=300)
plt.bar(xbarra, ybarra)
plt.title('Contador de mortes por sexo', fontdict={'fontname': 'League Gothic', 'fontsize': 20})
plt.xlabel('Sexo(1=F, 2=M)')
plt.ylabel('Contador')
plt.xticks([1,2])
plt.yticks([0,25000,50000,75000,100000])
plt.savefig('morteporsexo.png', dpi=300)
plt.show()

# %%
y = 
plt.plot(df['SEXO'], xbarra)
plt.yticks([0,12])
plt.figure(figsize=(7,6), dpi=500)
plit.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6566/1877313896.py in <module>
#       1 y = [df.loc[(df['MESOBITO'] == 1)], df.loc[(df['MESOBITO'] == 2)], df.loc[(df['MESOBITO'] == 3)], df.loc[(df['MESOBITO'] == 4)], df.loc[(df['MESOBITO'] == 5)], df.loc[(df['MESOBITO'] == 6)], df.loc[(df['MESOBITO'] == 7)], df.loc[(df['MESOBITO'] == 8)], df.loc[(df['MESOBITO'] == 9)], df.loc[(df['MESOBITO'] == 10)], df.loc[(df['MESOBITO'] == 11)], df.loc[(df['MESOBITO'] == 12)]]
# ----> 2 plt.plot(df['SEXO'], xbarra)
#       3 plt.yticks([0,12])
#       4 plt.figure(figsize=(7,6), dpi=500)
#       5 plit.show()
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# ...

# %%
plt.figure(figsize=(5,3), dpi=300)
plt.plot(df['MESOBITO'], df['IDADEANOS'])
plt.xlabel('IdadeAnos')
plt.ylabel('MesObito')
plt.yticks([1,25,50,75,100])
plt.xticks([2,4,6,8,10,12])
plt.savefig('testgraph.png', dpi=300)
plt.show()

# %%
x= [1, 2, 3, 4, 5]
y= [56831, 8270, 479, 44649, 233]
plt.figure(figsize=(5,4), dpi=300)
bars = plt.bar(x, y)
bars[1].set_hatch('/')
bars[3].set_hatch('/')
bars[2].set_hatch('/')
bars[4].set_hatch('/')
bars[0].set_hatch('/')
plt.title('Contador de mortes por Raca', fontdict={'fontname': 'League Gothic', 'fontsize': 20})
plt.xlabel('RACA(1-BRANCO;2-PRETO;3-AMARELO;4-PARDO;5-IDIGENA)')
plt.ylabel('Contador')
plt.xticks([1,2,3,4,5,])
plt.yticks([0, 30000, 60000])
plt.savefig('morteporraca.png', dpi=300)
plt.show()

# %%
df[df['RACACOR'] == 5].shape[0]
# Out:
# 233
